# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/suresh/dev/AV_face/src/warm-composite-350713-863405a712b4.json"

# %%
# !pip install google-cloud-vision

# %%
import pandas as pd

# %%
from google.cloud import vision
import io
client = vision.ImageAnnotatorClient()

# %%
loc_FFPlus = '/Users/suresh/dev/FaceConstruct/faceconstruct/faces/'

# %%
loc_FF = '/Users/suresh/dev/FaceConstruct/subset3/images/'
loc_FF_host = '/Users/suresh/dev/FaceConstruct/subset3/FairFace/'
lst_FairFace = ['77255.jpg', '9324.jpg', '84674.jpg', '70079.jpg', '38739.jpg', 
                '1208.jpg',  '44741.jpg', '7855.jpg', '77929.jpg', '65529.jpg', 
                '44207.jpg', '66870.jpg', '49192.jpg', '54669.jpg', '12737.jpg',
                '28090.jpg', '56440.jpg', '61175.jpg', '69932.jpg', '17653.jpg', 
                '21405.jpg', '25067.jpg', '26522.jpg', '27564.jpg', '15829.jpg',
                '29199.jpg', '80325.jpg', '69182.jpg', '55995.jpg', '24571.jpg', 
                '24293.jpg', '55074.jpg', '55995.jpg', '4249.jpg',  '353.jpg', 
                '2754.jpg',  '49240.jpg']
len(lst_FairFace)
# Out:
# 37

# %%
loc_FF_Plus = '/Users/suresh/dev/FaceConstruct/faceconstruct/FairFace_Plus/'
lst_FairFace_Plus = [
                'AfricaEthnicity/person-people-woman-hair-portrait-model-1083334-pxhere.com.jpg',
                'AfricaEthnicity/girl-hair-female-portrait-africa-child-937536-pxhere.com.jpg',
                'AfricaEthnicity/tribe-g0c47aa068_1920.jpg',
                'Angle/Two_Face_photo.jpg',
                'Angle/baby-g0df99370a_1920.jpg',
                'Angle/index.jpg',
                'Disability/Adam_Pearson_My_Amazing_Twin_–_Trailer_cropped.png',
                'FaceReflection/1024px-Face_inside_a_tank_31980102312.jpg',
                'FaceReflection/face-sky-light-head-cloud-darkness-1567015-pxhere.com.jpg',
                'FaceReflection/smartphone-man-black-and-white-people-technology-white-248363-pxhere.com.jpg',                
                'FaceTexture/Lips_of_steel_Unsplash.jpg',
                'FaceTexture/cracked-gd7ebf05ba_1920.jpg',
                'FaceTexture/man-snow-winter-people-white-ice-716559-pxhere.com.jpg',
                'FaceTexture/piqsels.com-id-owmjn.jpg',
                'FaceTexture/view-pattern-child-material-textile-face-914039-pxhere.com.jpg',
                'FaceTexture/wall-stones-face-stone-wall.jpg',
                'Facebeard/portrait-4296867_1280.jpg',
                'FacesWithBurns/Youssif_at_family_camp.png',
                'Freckles/girl-photography-portrait-color-blue-lip-707781-pxhere.com.jpg',
                'Freckles/piqsels.com-id-jdpzf.jpg',
                'Indigenous/ecuador-gfdcd61b62_1920.jpg',
                'Indigenous/laos-gb5c743bda_1920.jpg',
                'PartialFace/woman-face-head-water-sky-eye-1599997-pxhere.com.jpg',
                'Turban/man-person-people-hair-portrait-green-1221985-pxhere.com.jpg',
                'Turban/turban-people-dastar-wrinkle-human-headgear-1619826-pxhere.com.jpg'
                ]
len(lst_FairFace_Plus)
# Out:
# 25

# %% [markdown]
# # Main Function to Analyze the images

# %%
import os

#    https://github.com/bsairesearch/faceconstruct/blob/main/faces/andro.jpeg
#loc = '/Users/suresh/dev/FaceConstruct/faceconstruct/faces/'
def get_imageanalysis(lst, loc=None):
    lst_moves = []
    lst_conf = []
    print("\n\nLocation = " + loc)
    i = 0
    #for filename in os.listdir(loc):
    for filename in lst:
        print(str(i) + ". " + loc + filename)
        i = i + 1
        sleep(2)
        with io.open(loc + filename, 'rb') as image_file:
            content = image_file.read()        
            image = vision.Image(content=content)
            response = client.face_detection(image=image)
            faces = response.face_annotations
            print(filename +"==" + str(faces))
            conf_score=-1
            if len(faces) > 0:
                conf_score = round(faces[0].detection_confidence * 100)
            lst_conf.append(filename +"==" + str(conf_score))
            lst_moves.append('mv ' + loc_FF + filename + '  ' + loc_FF_host)
            
            print(filename+"\n############\n")
            #print(filename +"==" + str(faces))
        
    print("\n############\n")
    print(lst_conf)
    print(*lst_conf, sep = "\n")

    print("\n############\n")
    print(lst_moves)
    print(*lst_moves, sep = "\n")    
    
    print('\n***DONE***\n')

# %%
lst_moves = []
for filename in lst_FairFace:
    lst_moves.append('mv ' + loc_FF + filename + '  ' + loc_FF_host)
    
for mv in lst_moves:
    print(mv)
# Out:
# mv /Users/suresh/dev/FaceConstruct/subset3/images/77255.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/9324.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/84674.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/70079.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/38739.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/1208.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/44741.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# mv /Users/suresh/dev/FaceConstruct/subset3/images/7855.jpg  /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# ...

# %%
filehandler = open("gcp_data_FAIRFACE_v2.txt", 'wt')
data = str(gcp_data)
filehandler.write(data)

# %%
len(gcp_data)

# %%
gcp_data['0']

# %%
for keys, values in gcp_data.items():
    
    
        if values[0].detection_confidence < 0.60:
            print(keys)

# %%
### RUN2

import os

#    https://github.com/bsairesearch/faceconstruct/blob/main/faces/andro.jpeg
loc = '/Users/suresh/dev/FaceConstruct/faceconstruct/faces/'
for filename in os.listdir(loc):
    with io.open(loc + filename, 'rb') as image_file:
        content = image_file.read()        
        image = vision.Image(content=content)
        response = client.face_detection(image=image)
        faces = response.face_annotations
        gcp_data = faces
        print(filename +"==" + str(gcp_data))
        print(filename+"\n############\n")
print('\n***DONE***\n')

# %%
get_imageanalysis(lst_FairFace, loc_FF_host)
# Out:
# Location = /Users/suresh/dev/FaceConstruct/subset3/FairFace/
# 0. /Users/suresh/dev/FaceConstruct/subset3/FairFace/7078.jpg
# 7078.jpg==[bounding_poly {
#   vertices {
#   }
#   vertices {
#     x: 223
#   }
#   vertices {
#     x: 223
#     y: 223
#   }
#   vertices {
#     y: 223
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 3
#   }
#   vertices {
#     x: 216
#   }
#   vertices {
#     x: 216
#     y: 201
#   }
#   vertices {
#     x: 3
#     y: 201
#   }
# }
# landmarks {
#   type_: LEFT_EYE
#   position {
#     x: 69.83248901367188
#     y: 67.19671630859375
#     z: 0.00035381317138671875
#   }
# }
# landmarks {
#   type_: RIGHT_EYE
#   position {
#     x: 151.39207458496094
#     y: 71.3753433227539
#     z: 14.856731414794922
#   }
# }
# landmarks {
#   type_: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 44.14850616455078
#     y: 39.77062225341797
#     z: 4.317876815795898
#   }
# }
# landmarks {
#   type_: RIGHT_OF_LEFT_EYEBROW
#   position {
# ...

# %% [markdown]
# # FairFace Plus Run

# %%
get_imageanalysis(lst_FairFace_Plus,loc_FF_Plus)
# Out:
# Location = /Users/suresh/dev/FaceConstruct/faceconstruct/FairFace_Plus/
# 0. /Users/suresh/dev/FaceConstruct/faceconstruct/FairFace_Plus/AfricaEthnicity/person-people-woman-hair-portrait-model-1083334-pxhere.com.jpg
# AfricaEthnicity/person-people-woman-hair-portrait-model-1083334-pxhere.com.jpg==[bounding_poly {
#   vertices {
#     x: 166
#     y: 361
#   }
#   vertices {
#     x: 1933
#     y: 361
#   }
#   vertices {
#     x: 1933
#     y: 2415
#   }
#   vertices {
#     x: 166
#     y: 2415
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 299
#     y: 854
#   }
#   vertices {
#     x: 1745
#     y: 854
#   }
#   vertices {
#     x: 1745
#     y: 2376
#   }
#   vertices {
#     x: 299
#     y: 2376
#   }
# }
# landmarks {
#   type_: LEFT_EYE
#   position {
#     x: 766.7174682617188
#     y: 1562.4840087890625
#     z: 0.0054931640625
#   }
# }
# landmarks {
#   type_: RIGHT_EYE
#   position {
#     x: 1287.2744140625
#     y: 1550.842529296875
#     z: -35.95152282714844
# ...

# %%
# FairFace Plus Second Run
from time import sleep
get_imageanalysis(lst_FairFace_Plus,loc_FF_Plus)
# Out:
# Location = /Users/suresh/dev/FaceConstruct/faceconstruct/FairFace_Plus/
# 0. /Users/suresh/dev/FaceConstruct/faceconstruct/FairFace_Plus/AfricaEthnicity/person-people-woman-hair-portrait-model-1083334-pxhere.com.jpg
# AfricaEthnicity/person-people-woman-hair-portrait-model-1083334-pxhere.com.jpg==[bounding_poly {
#   vertices {
#     x: 166
#     y: 361
#   }
#   vertices {
#     x: 1933
#     y: 361
#   }
#   vertices {
#     x: 1933
#     y: 2415
#   }
#   vertices {
#     x: 166
#     y: 2415
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 299
#     y: 854
#   }
#   vertices {
#     x: 1745
#     y: 854
#   }
#   vertices {
#     x: 1745
#     y: 2376
#   }
#   vertices {
#     x: 299
#     y: 2376
#   }
# }
# landmarks {
#   type_: LEFT_EYE
#   position {
#     x: 766.7174682617188
#     y: 1562.4840087890625
#     z: 0.0054931640625
#   }
# }
# landmarks {
#   type_: RIGHT_EYE
#   position {
#     x: 1287.2744140625
#     y: 1550.842529296875
#     z: -35.95152282714844
# ...
